# %%
import pandas as pd

# %%
url = "https://drive.google.com/uc?id=1wvNExa2m2Mh_zY2ELWsE9skiKbDd8SSN"  
btc = pd.read_csv(url)
print(btc.head())
# Out:
#         Price            Close             High              Low  \
# 0      Ticker          BTC-USD          BTC-USD          BTC-USD
# 1        Date              NaN              NaN              NaN
# 2  2021-01-01   29374.15234375  29600.626953125    28803.5859375
# 3  2021-01-02  32127.267578125    33155.1171875  29091.181640625
# 4  2021-01-03    32782.0234375   34608.55859375   32052.31640625
#
#               Open       Volume
# 0          BTC-USD      BTC-USD
# 1              NaN          NaN
# 2  28994.009765625  40730301359
# 3  29376.455078125  67865420765
# 4  32129.408203125  78665235202

# %%
bnb_url = "https://drive.google.com/uc?id=1vgTWftWI8y289S8c8KE85ozsHSjWu_pg"  
bnb = pd.read_csv(bnb_url)
print(bnb.head())
# Out:
#         Price              Close               High                 Low  \
# 0      Ticker            BNB-USD            BNB-USD             BNB-USD
# 1        Date                NaN                NaN                 NaN
# 2  2021-01-01  37.90501022338867  38.92817687988281   37.04630661010742
# 3  2021-01-02  38.24159240722656  38.83625411987305  36.925601959228516
# 4  2021-01-03  41.14897918701172   41.6063232421875    37.8181037902832
#
#                  Open     Volume
# 0             BNB-USD    BNB-USD
# 1                 NaN        NaN
# 2   37.37457275390625  459165743
# 3   37.91710662841797  521965394
# 4  38.253726959228516  758008613

# %%
eth_url = "https://drive.google.com/uc?id=1ZMuVs5IW8FuJHWipbF0vWm1L-Xr-F-tg"  
eth = pd.read_csv(eth_url)
print(eth.head())
# Out:
#         Price              Close                High                Low  \
# 0      Ticker            ETH-USD             ETH-USD            ETH-USD
# 1        Date                NaN                 NaN                NaN
# 2  2021-01-01  730.3675537109375   749.2018432617188   719.792236328125
# 3  2021-01-02  774.5349731445312   786.7984619140625  718.1094970703125
# 4  2021-01-03  975.5076904296875  1006.5650024414062  771.5616455078125
#
#                 Open       Volume
# 0            ETH-USD      ETH-USD
# 1                NaN          NaN
# 2  737.7083740234375  13652004358
# 3  730.4026489257812  19740771179
# 4  774.5118408203125  45200463368

# %%
sol_url = "https://drive.google.com/uc?id=1jOH7TcSpB6MKiT9W4VpHCSzZzXyNMlNq"  
sol = pd.read_csv(sol_url)
print(sol.head())
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker             SOL-USD             SOL-USD             SOL-USD
# 1        Date                 NaN                 NaN                 NaN
# 2  2021-01-01  1.8420840501785278  1.8596559762954712  1.5020380020141602
# 3  2021-01-02  1.7992750406265259  1.9892950057983398  1.7214820384979248
# 4  2021-01-03  2.1617519855499268   2.364980936050415  1.7999019622802734
#
#                  Open    Volume
# 0             SOL-USD   SOL-USD
# 1                 NaN       NaN
# 2  1.5097750425338745  25722549
# 3  1.8455859422683716  31671064
# 4  1.7999019622802734  55073422

# %%
xrp_url = "https://drive.google.com/uc?id=1CS3d-1syse7EjpF5n5rjeW1yMJFsYLJx"
xrp = pd.read_csv(xrp_url)
print(xrp.head())
# Out:
#         Price                Close                 High                  Low  \
# 0      Ticker              XRP-USD              XRP-USD              XRP-USD
# 1        Date                  NaN                  NaN                  NaN
# 2  2021-01-01  0.23744399845600128   0.2492700070142746  0.21728800237178802
# 3  2021-01-02   0.2216549962759018  0.23838800191879272  0.21581600606441498
# 4  2021-01-03   0.2258480042219162  0.23774099349975586  0.21716700494289398
#
#                   Open      Volume
# 0              XRP-USD     XRP-USD
# 1                  NaN         NaN
# 2   0.2198449969291687  5888429287
# 3  0.23767000436782837  4773658725
# 4  0.22174400091171265  5109898871

# %%
btc = btc.iloc[2:]
bnb = bnb.iloc[2:]
eth = eth.iloc[2:]
sol = sol.iloc[2:] 
xrp = xrp.iloc[2:]

# %%
btc.head()
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
#  3   Low     1461 non-null   object
#  4   Open    1461 non-null   object
#  5   Volume  1461 non-null   object
# dtypes: object(6)
# memory usage: 68.6+ KB

# %%
bnb.head()
bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
#  3   Low     1461 non-null   object
#  4   Open    1461 non-null   object
#  5   Volume  1461 non-null   object
# dtypes: object(6)
# memory usage: 68.6+ KB

# %%
eth.head()
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
#  3   Low     1461 non-null   object
#  4   Open    1461 non-null   object
#  5   Volume  1461 non-null   object
# dtypes: object(6)
# memory usage: 68.6+ KB

# %%
sol.head()
sol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
#  3   Low     1461 non-null   object
#  4   Open    1461 non-null   object
#  5   Volume  1461 non-null   object
# dtypes: object(6)
# memory usage: 68.6+ KB

# %%
xrp.head()
xrp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
#  3   Low     1461 non-null   object
#  4   Open    1461 non-null   object
#  5   Volume  1461 non-null   object
# dtypes: object(6)
# memory usage: 68.6+ KB

# %%
btc.isnull().sum()
# Out:
# Price     0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
bnb.isnull().sum()
# Out:
# Price     0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
eth.isnull().sum()
# Out:
# Price     0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
sol.isnull().sum()
# Out:
# Price     0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
xrp.isnull().sum()
# Out:
# Price     0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
btc.fillna(method="ffill", inplace=True)
bnb.fillna(method="ffill", inplace=True)
eth.fillna(method="ffill", inplace=True)
sol.fillna(method="ffill", inplace=True)
xrp.fillna(method="ffill", inplace=True)
# Out:
# /tmp/ipykernel_545/1080771994.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   btc.fillna(method="ffill", inplace=True)
# /tmp/ipykernel_545/1080771994.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   bnb.fillna(method="ffill", inplace=True)
# /tmp/ipykernel_545/1080771994.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   eth.fillna(method="ffill", inplace=True)
# /tmp/ipykernel_545/1080771994.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sol.fillna(method="ffill", inplace=True)
# ...

# %%
btc = btc[~btc.index.duplicated()]
bnb = bnb[~bnb.index.duplicated()]
eth = eth[~eth.index.duplicated()]
sol = sol[~sol.index.duplicated()]
xrp = xrp[~xrp.index.duplicated()]

# %%
btc.columns = ["Date","Close","High","Low","Open","Volume"]
bnb.columns = ["Date","Close","High","Low","Open","Volume"]
eth.columns = ["Date","Close","High","Low","Open","Volume"]
sol.columns = ["Date","Close","High","Low","Open","Volume"]
xrp.columns = ["Date","Close","High","Low","Open","Volume"]

# %%
btc["Date"] = pd.to_datetime(btc["Date"])
bnb["Date"] = pd.to_datetime(bnb["Date"])
eth["Date"] = pd.to_datetime(eth["Date"])
sol["Date"] = pd.to_datetime(sol["Date"])
xrp["Date"] = pd.to_datetime(xrp["Date"])

# %%
btc = btc.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
bnb = bnb.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
eth = eth.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
sol = sol.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
xrp = xrp.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})

# %%
btc = btc.sort_values("Date")
bnb = bnb.sort_values("Date")
eth = eth.sort_values("Date")
sol = sol.sort_values("Date")
xrp = xrp.sort_values("Date")

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = ["Close", "High", "Low", "Open", "Volume"]
btc[features] = scaler.fit_transform(btc[features])

# %%
scaler = StandardScaler()
features = ["Close", "High", "Low", "Open", "Volume"]
bnb[features] = scaler.fit_transform(bnb[features])

# %%
scaler = StandardScaler()
features = ["Close", "High", "Low", "Open", "Volume"]
eth[features] = scaler.fit_transform(eth[features])

# %%
scaler = StandardScaler()
features = ["Close", "High", "Low", "Open", "Volume"]
sol[features] = scaler.fit_transform(sol[features])

# %%
scaler = StandardScaler()
features = ["Close", "High", "Low", "Open", "Volume"]
xrp[features] = scaler.fit_transform(xrp[features])

# %%
import matplotlib.pyplot as plt
btc.describe()
# Out:
#                                 Date         Close          High  \
# count                           1461  1.461000e+03  1.461000e+03
# mean   2023-01-01 00:00:00.000000256  1.750824e-16 -1.945360e-17
# min              2021-01-01 00:00:00 -1.426916e+00 -1.421171e+00
# 25%              2022-01-01 00:00:00 -8.161583e-01 -8.201106e-01
# 50%              2023-01-01 00:00:00 -1.518554e-01 -1.432229e-01
# 75%              2024-01-01 00:00:00  7.863811e-01  7.820485e-01
# max              2024-12-31 00:00:00  3.376025e+00  3.373622e+00
# std                              NaN  1.000342e+00  1.000342e+00
#
#                 Low          Open        Volume
# count  1.461000e+03  1.461000e+03  1.461000e+03
# mean  -1.556288e-16  1.167216e-16  1.167216e-16
# min   -1.416669e+00 -1.428149e+00 -1.326583e+00
# 25%   -8.042136e-01 -8.163039e-01 -6.483691e-01
# 50%   -1.558720e-01 -1.515699e-01 -1.947384e-01
# 75%    7.773213e-01  7.906372e-01  3.157980e-01
# ...

# %%
bnb.describe()
# Out:
#                                 Date         Close          High  \
# count                           1461  1.461000e+03  1.461000e+03
# mean   2023-01-01 00:00:00.000000256 -3.890720e-17 -9.726800e-17
# min              2021-01-01 00:00:00 -2.264677e+00 -2.263447e+00
# 25%              2022-01-01 00:00:00 -7.231585e-01 -7.239190e-01
# 50%              2023-01-01 00:00:00 -3.618174e-01 -3.559869e-01
# 75%              2024-01-01 00:00:00  9.424008e-01  9.446217e-01
# max              2024-12-31 00:00:00  2.475536e+00  2.631120e+00
# std                              NaN  1.000342e+00  1.000342e+00
#
#                 Low          Open        Volume
# count  1.461000e+03  1.461000e+03  1.461000e+03
# mean  -1.750824e-16  1.459020e-16  3.890720e-17
# min   -2.271928e+00 -2.263952e+00 -1.034336e+00
# 25%   -7.226610e-01 -7.199923e-01 -6.800753e-01
# 50%   -3.466891e-01 -3.588293e-01 -1.679078e-01
# 75%    9.287983e-01  9.445056e-01  2.597834e-01
# ...

# %%
eth.describe()
# Out:
#                                 Date         Close          High  \
# count                           1461  1.461000e+03  1.461000e+03
# mean   2023-01-01 00:00:00.000000256  1.945360e-16  5.836080e-17
# min              2021-01-01 00:00:00 -1.915453e+00 -1.909757e+00
# 25%              2022-01-01 00:00:00 -8.287900e-01 -8.235436e-01
# 50%              2023-01-01 00:00:00 -1.818387e-01 -1.711790e-01
# 75%              2024-01-01 00:00:00  8.046795e-01  8.016189e-01
# max              2024-12-31 00:00:00  2.761902e+00  2.702483e+00
# std                              NaN  1.000342e+00  1.000342e+00
#
#                 Low          Open        Volume
# count  1.461000e+03  1.461000e+03  1.461000e+03
# mean   2.918040e-16 -2.723504e-16  1.556288e-16
# min   -1.907781e+00 -1.910975e+00 -1.335940e+00
# 25%   -8.142950e-01 -8.270712e-01 -7.131985e-01
# 50%   -1.914284e-01 -1.812088e-01 -1.852858e-01
# 75%    8.232263e-01  8.047455e-01  4.001380e-01
# ...

# %%
sol.describe()
# Out:
#                                 Date         Close          High          Low  \
# count                           1461  1.461000e+03  1.461000e+03  1461.000000
# mean   2023-01-01 00:00:00.000000256  1.167216e-16 -9.726800e-17     0.000000
# min              2021-01-01 00:00:00 -1.177565e+00 -1.182313e+00    -1.176992
# 25%              2022-01-01 00:00:00 -8.584571e-01 -8.631879e-01    -0.853071
# 50%              2023-01-01 00:00:00 -5.556804e-01 -5.450190e-01    -0.554831
# 75%              2024-01-01 00:00:00  9.039760e-01  8.887902e-01     0.901202
# max              2024-12-31 00:00:00  2.657908e+00  2.593897e+00     2.724027
# std                              NaN  1.000342e+00  1.000342e+00     1.000342
#
#                Open        Volume
# count  1.461000e+03  1.461000e+03
# mean   1.069948e-16 -3.890720e-17
# min   -1.180173e+00 -9.498127e-01
# 25%   -8.568857e-01 -7.183094e-01
# 50%   -5.542804e-01 -2.773909e-01
# 75%    9.058718e-01  3.784329e-01
# ...

# %%
xrp.describe()
# Out:
#                                 Date         Close          High  \
# count                           1461  1.461000e+03  1.461000e+03
# mean   2023-01-01 00:00:00.000000256 -1.167216e-16 -5.836080e-17
# min              2021-01-01 00:00:00 -1.201660e+00 -1.151823e+00
# 25%              2022-01-01 00:00:00 -5.372905e-01 -5.450172e-01
# 50%              2023-01-01 00:00:00 -3.148124e-01 -3.186386e-01
# 75%              2024-01-01 00:00:00  2.071557e-01  2.094419e-01
# max              2024-12-31 00:00:00  5.662115e+00  5.675124e+00
# std                              NaN  1.000342e+00  1.000342e+00
#
#                 Low          Open        Volume
# count  1.461000e+03  1.461000e+03  1.461000e+03
# mean  -5.836080e-17  5.836080e-17  3.890720e-17
# min   -1.230776e+00 -1.209272e+00 -6.525396e-01
# 25%   -5.442741e-01 -5.366206e-01 -4.672280e-01
# 50%   -3.094276e-01 -3.128306e-01 -3.359627e-01
# 75%    2.234716e-01  2.112838e-01  2.110892e-02
# ...

# %%
btc["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
bnb.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
eth.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
sol.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
xrp.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
import numpy as np
btc["Volume"] = np.log1p(btc["Volume"])
bnb["Volume"] = np.log1p(bnb["Volume"])
eth["Volume"] = np.log1p(eth["Volume"])
sol["Volume"] = np.log1p(sol["Volume"])
xrp["Volume"] = np.log1p(xrp["Volume"])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
btc.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
bnb.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
eth.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
sol.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
xrp.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
btc["Volume"] = btc["Volume"].clip(
    btc["Volume"].quantile(0.01),
    btc["Volume"].quantile(0.99)
)
bnb["Volume"] = bnb["Volume"].clip(
    bnb["Volume"].quantile(0.01),
    bnb["Volume"].quantile(0.99)
)
eth["Volume"] = eth["Volume"].clip(
    eth["Volume"].quantile(0.01),
    eth["Volume"].quantile(0.99)
)
sol["Volume"] = sol["Volume"].clip(
    sol["Volume"].quantile(0.01),
    sol["Volume"].quantile(0.99)
)
xrp["Volume"] = xrp["Volume"].clip(
    xrp["Volume"].quantile(0.01), 
    xrp["Volume"].quantile(0.99)
)

# %%
btc.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
bnb.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
eth.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
sol.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
xrp.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
btc["Volume"] = scaler.fit_transform(btc[["Volume"]])
bnb["Volume"] = scaler.fit_transform(bnb[["Volume"]])
eth["Volume"] = scaler.fit_transform(eth[["Volume"]])
sol["Volume"] = scaler.fit_transform(sol[["Volume"]])
xrp["Volume"] = scaler.fit_transform(xrp[["Volume"]])

# %%
btc.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
bnb.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
eth.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
sol.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
xrp.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

btc["Daily_Return"] = btc["Close"].pct_change()
btc[["Date", "Close", "Daily_Return"]].head()
# Out:
#         Date     Close  Daily_Return
# 2 2021-01-01 -0.704674           NaN
# 3 2021-01-02 -0.558326     -0.207682
# 4 2021-01-03 -0.523521     -0.062338
# 5 2021-01-04 -0.566584      0.082257
# 6 2021-01-05 -0.459179     -0.189566

# %%
btc["Daily_Return"].plot()
plt.show()

# %%
bnb["Daily_Return"] = bnb["Close"].pct_change()
bnb[["Date", "Close", "Daily_Return"]].head()
# Out:
#         Date     Close  Daily_Return
# 2 2021-01-01 -2.264677           NaN
# 3 2021-01-02 -2.262438     -0.000989
# 4 2021-01-03 -2.243091     -0.008551
# 5 2021-01-04 -2.244573      0.000660
# 6 2021-01-05 -2.239194     -0.002396

# %%
bnb["Daily_Return"].plot()
plt.show()

# %%
eth["Daily_Return"] = eth["Close"].pct_change()
eth[["Date", "Close", "Daily_Return"]].head()
# Out:
#         Date     Close  Daily_Return
# 2 2021-01-01 -1.915453           NaN
# 3 2021-01-02 -1.864840     -0.026423
# 4 2021-01-03 -1.634540     -0.123496
# 5 2021-01-04 -1.560370     -0.045377
# 6 2021-01-05 -1.491874     -0.043897

# %%
eth["Daily_Return"].plot()
plt.show()

# %%
sol["Daily_Return"] = sol["Close"].pct_change()
sol[["Date", "Close", "Daily_Return"]].head()
# Out:
#         Date     Close  Daily_Return
# 2 2021-01-01 -1.176926           NaN
# 3 2021-01-02 -1.177565      0.000543
# 4 2021-01-03 -1.172158     -0.004591
# 5 2021-01-04 -1.167335     -0.004115
# 6 2021-01-05 -1.172226      0.004190

# %%
sol["Daily_Return"].plot()
plt.show()

# %%
xrp["Daily_Return"] = xrp["Close"].pct_change()
xrp[["Date", "Close", "Daily_Return"]].head()
# Out:
#         Date     Close  Daily_Return
# 2 2021-01-01 -1.158174           NaN
# 3 2021-01-02 -1.201660      0.037547
# 4 2021-01-03 -1.190111     -0.009610
# 5 2021-01-04 -1.160287     -0.025060
# 6 2021-01-05 -1.187627      0.023564

# %%
xrp["Daily_Return"].plot()
plt.show()

# %%
btc["Volume"].describe()
# Out:
# count    1.354000e+03
# mean    -1.533061e-01
# std      9.034329e-01
# min     -3.171881e+00
# 25%     -5.843284e-01
# 50%     -1.257675e-17
# 75%      4.156716e-01
# max      1.491156e+00
# Name: Volume, dtype: float64

# %%
btc["Volume"].plot()
plt.show()

# %%
bnb["Volume"].describe()
# Out:
# count    1454.000000
# mean       -0.215376
# std         0.810162
# min        -2.785512
# 25%        -0.695357
# 50%         0.000000
# 75%         0.304643
# max         1.300216
# Name: Volume, dtype: float64

# %%
bnb["Volume"].plot()
plt.show()

# %%
eth["Volume"].describe()
# Out:
# count    1.296000e+03
# mean    -1.441215e-01
# std      8.674023e-01
# min     -2.973567e+00
# 25%     -5.850342e-01
# 50%     -5.854692e-18
# 75%      4.149658e-01
# max      1.348795e+00
# Name: Volume, dtype: float64

# %%
eth["Volume"].plot()
plt.show()

# %%
sol["Volume"].describe()
# Out:
# count    1461.000000
# mean       -0.087043
# std         0.640080
# min        -1.527232
# 25%        -0.593276
# 50%         0.000000
# 75%         0.406724
# max         1.225397
# Name: Volume, dtype: float64

# %%
sol["Volume"].plot()
plt.show()

# %%
xrp["Volume"].describe()
# Out:
# count    1461.000000
# mean        0.276510
# std         0.877021
# min        -0.840218
# 25%        -0.338551
# 50%         0.000000
# 75%         0.661449
# max         3.241552
# Name: Volume, dtype: float64

# %%
xrp["Volume"].plot()
plt.show()

# %%
btc["Close_lag_1"] = btc["Close"].shift(1)
btc["Close_lag_7"] = btc["Close"].shift(7)
btc["Close_lag_14"] = btc["Close"].shift(14)

# %%
btc["Close_lag_30"] = btc["Close"].shift(30)
btc["Close_lag_90"] = btc["Close"].shift(90)
btc["Close_lag_180"] = btc["Close"].shift(180)

# %%
bnb["Close_lag_1"] = bnb["Close"].shift(1)
bnb["Close_lag_7"] = bnb["Close"].shift(7)
bnb["Close_lag_14"] = bnb["Close"].shift(14)

# %%
bnb["Close_lag_30"] = bnb["Close"].shift(30)
bnb["Close_lag_90"] = bnb["Close"].shift(90)
bnb["Close_lag_180"] = bnb["Close"].shift(180)

# %%
eth["Close_lag_1"] = eth["Close"].shift(1)
eth["Close_lag_7"] = eth["Close"].shift(7)
eth["Close_lag_14"] = eth["Close"].shift(14)

# %%
eth["Close_lag_30"] = eth["Close"].shift(30)
eth["Close_lag_90"] = eth["Close"].shift(90)
eth["Close_lag_180"] = eth["Close"].shift(180)

# %%
sol["Close_lag_1"] = sol["Close"].shift(1)
sol["Close_lag_7"] = sol["Close"].shift(7)
sol["Close_lag_14"] = sol["Close"].shift(14)

# %%
sol["Close_lag_30"] = sol["Close"].shift(30)
sol["Close_lag_90"] = sol["Close"].shift(90)
sol["Close_lag_180"] = sol["Close"].shift(180)

# %%
xrp["Close_lag_1"] = xrp["Close"].shift(1)
xrp["Close_lag_7"] = xrp["Close"].shift(7)
xrp["Close_lag_14"] = xrp["Close"].shift(14)

# %%
sol["Close_lag_30"] = sol["Close"].shift(30)
sol["Close_lag_90"] = sol["Close"].shift(90)
sol["Close_lag_180"] = sol["Close"].shift(180)

# %%
btc["MA_7"] = btc["Close"].rolling(7).mean()
btc["MA_21"] = btc["Close"].rolling(21).mean()
btc["MA_60"] = btc["Close"].rolling(60).mean()
btc["MA_180"] = btc["Close"].rolling(180).mean()

# %%
bnb["MA_7"] = bnb["Close"].rolling(7).mean()
bnb["MA_21"] = bnb["Close"].rolling(21).mean()
bnb["MA_60"] = bnb["Close"].rolling(60).mean()
bnb["MA_180"] = bnb["Close"].rolling(180).mean()

# %%
eth["MA_7"] = eth["Close"].rolling(7).mean()
eth["MA_21"] = eth["Close"].rolling(21).mean()
eth["MA_60"] = eth["Close"].rolling(60).mean()
eth["MA_180"] = eth["Close"].rolling(180).mean()

# %%
sol["MA_7"] = sol["Close"].rolling(7).mean()
sol["MA_21"] = sol["Close"].rolling(21).mean()
sol["MA_60"] = sol["Close"].rolling(60).mean()
sol["MA_180"] = sol["Close"].rolling(180).mean()

# %%
xrp["MA_7"] = xrp["Close"].rolling(7).mean()
xrp["MA_21"] = xrp["Close"].rolling(21).mean()
xrp["MA_60"] = xrp["Close"].rolling(60).mean()
xrp["MA_180"] = xrp["Close"].rolling(180).mean()

# %%
btc["Volatility_7"] = btc["Daily_Return"].rolling(7).std()
btc["Volatility_21"] = btc["Daily_Return"].rolling(21).std()
btc["Volatility_60"] = btc["Daily_Return"].rolling(60).std()
btc["Volatility_180"] = btc["Daily_Return"].rolling(180).std()

# %%
bnb["Volatility_7"] = bnb["Daily_Return"].rolling(7).std()
bnb["Volatility_21"] = bnb["Daily_Return"].rolling(21).std()
bnb["Volatility_60"] = bnb["Daily_Return"].rolling(60).std()
bnb["Volatility_180"] = bnb["Daily_Return"].rolling(180).std()

# %%
eth["Volatility_7"] = eth["Daily_Return"].rolling(7).std()
eth["Volatility_21"] = eth["Daily_Return"].rolling(21).std()
eth["Volatility_60"] = eth["Daily_Return"].rolling(60).std()
eth["Volatility_180"] = eth["Daily_Return"].rolling(180).std()

# %%
sol["Volatility_7"] = sol["Daily_Return"].rolling(7).std()
sol["Volatility_21"] = sol["Daily_Return"].rolling(21).std()
sol["Volatility_60"] = sol["Daily_Return"].rolling(60).std()
sol["Volatility_180"] = sol["Daily_Return"].rolling(180).std()

# %%
xrp["Volatility_7"] = xrp["Daily_Return"].rolling(7).std()
xrp["Volatility_21"] = xrp["Daily_Return"].rolling(21).std()
xrp["Volatility_60"] = xrp["Daily_Return"].rolling(60).std()
xrp["Volatility_180"] = xrp["Daily_Return"].rolling(180).std()

# %%
btc["HL_Spread"] = (btc["High"] - btc["Low"]) / btc["Close"]

# %%
bnb["HL_Spread"] = (bnb["High"] - bnb["Low"]) / bnb["Close"]

# %%
eth["HL_Spread"] = (eth["High"] - eth["Low"]) / eth["Close"]

# %%
sol["HL_Spread"] = (sol["High"] - sol["Low"]) / sol["Close"]

# %%
xrp["HL_Spread"] = (xrp["High"] - xrp["Low"]) / xrp["Close"]

# %%
btc["Volume_MA_7"] = btc["Volume"].rolling(7).mean()
btc["Volume_Change"] = btc["Volume"].pct_change()
btc["Volume_MA_21"] = btc["Volume"].rolling(21).mean()
btc["Volume_Change"] = btc["Volume"].pct_change()
btc["Volume_MA_60"] = btc["Volume"].rolling(60).mean()
btc["Volume_Change"] = btc["Volume"].pct_change()
btc["Volume_MA_180"] = btc["Volume"].rolling(180).mean()
btc["Volume_Change"] = btc["Volume"].pct_change()
# Out:
# /tmp/ipykernel_545/933212557.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   btc["Volume_Change"] = btc["Volume"].pct_change()
# /tmp/ipykernel_545/933212557.py:4: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   btc["Volume_Change"] = btc["Volume"].pct_change()
# /tmp/ipykernel_545/933212557.py:6: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ...

# %%
bnb["Volume_MA_7"] = bnb["Volume"].rolling(7).mean()
bnb["Volume_Change"] = bnb["Volume"].pct_change()
bnb["Volume_MA_21"] = bnb["Volume"].rolling(21).mean()
bnb["Volume_Change"] = bnb["Volume"].pct_change()
bnb["Volume_MA_60"] = bnb["Volume"].rolling(60).mean()
bnb["Volume_Change"] = bnb["Volume"].pct_change()
bnb["Volume_MA_180"] = bnb["Volume"].rolling(180).mean()
bnb["Volume_Change"] = bnb["Volume"].pct_change()
# Out:
# /tmp/ipykernel_545/2858179059.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   bnb["Volume_Change"] = bnb["Volume"].pct_change()
# /tmp/ipykernel_545/2858179059.py:4: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   bnb["Volume_Change"] = bnb["Volume"].pct_change()
# /tmp/ipykernel_545/2858179059.py:6: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ...

# %%
eth["Volume_MA_7"] = eth["Volume"].rolling(7).mean()
eth["Volume_Change"] = eth["Volume"].pct_change()
eth["Volume_MA_21"] = eth["Volume"].rolling(21).mean()
eth["Volume_Change"] = eth["Volume"].pct_change()  
eth["Volume_MA_60"] = eth["Volume"].rolling(60).mean()
eth["Volume_Change"] = eth["Volume"].pct_change()
eth["Volume_MA_180"] = eth["Volume"].rolling(180).mean()
eth["Volume_Change"] = eth["Volume"].pct_change()
# Out:
# /tmp/ipykernel_545/1762564756.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   eth["Volume_Change"] = eth["Volume"].pct_change()
# /tmp/ipykernel_545/1762564756.py:4: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   eth["Volume_Change"] = eth["Volume"].pct_change()
# /tmp/ipykernel_545/1762564756.py:6: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ...

# %%
sol["Volume_MA_7"] = sol["Volume"].rolling(7).mean()
sol["Volume_Change"] = sol["Volume"].pct_change()
sol["Volume_MA_21"] = sol["Volume"].rolling(21).mean()
sol["Volume_Change"] = sol["Volume"].pct_change()
sol["Volume_MA_60"] = sol["Volume"].rolling(60).mean()
sol["Volume_Change"] = sol["Volume"].pct_change()
sol["Volume_MA_180"] = sol["Volume"].rolling(180).mean()
sol["Volume_Change"] = sol["Volume"].pct_change()

# %%
xrp["Volume_MA_7"] = xrp["Volume"].rolling(7).mean()
xrp["Volume_Change"] = xrp["Volume"].pct_change()
xrp["Volume_MA_21"] = xrp["Volume"].rolling(21).mean()
xrp["Volume_Change"] = xrp["Volume"].pct_change()
xrp["Volume_MA_60"] = xrp["Volume"].rolling(60).mean()
xrp["Volume_Change"] = xrp["Volume"].pct_change()
xrp["Volume_MA_180"] = xrp["Volume"].rolling(180).mean()
xrp["Volume_Change"] = xrp["Volume"].pct_change()

# %%
btc["Target_Close"] = btc["Close"].shift(-1)
bnb["Target_Close"] = bnb["Close"].shift(-1)
eth["Target_Close"] = eth["Close"].shift(-1)   
xrp["Target_Close"] = xrp["Close"].shift(-1)
sol["Target_Close"] = sol["Close"].shift(-1)

# %%
btc["Target_Return_7d"] = (
    btc["Close"].shift(-7) / btc["Close"] - 1
)
bnb["Target_Return_7d"] = (
    bnb["Close"].shift(-7) / bnb["Close"] - 1
)
eth["Target_Return_7d"] = (
    eth["Close"].shift(-7) / eth["Close"] - 1
)
sol["Target_Return_7d"] = (
    sol["Close"].shift(-7) / sol["Close"] - 1
)
xrp["Target_Return_7d"] = (
    xrp["Close"].shift(-7) / xrp["Close"] - 1
)

# %%
btc["Target_Return_30d"] = (
    btc["Close"].shift(-30) / btc["Close"] - 1
)
bnb["Target_Return_30d"] = (
    bnb["Close"].shift(-30) / bnb["Close"] - 1
)
eth["Target_Return_30d"] = (
    eth["Close"].shift(-30) / eth["Close"] - 1
)
sol["Target_Return_30d"] = (
    sol["Close"].shift(-30) / sol["Close"] - 1
)
xrp["Target_Return_30d"] = (
    xrp["Close"].shift(-30) / xrp["Close"] - 1
)

# %%
btc["Target_Return_365d"] = (
    btc["Close"].shift(-365) / btc["Close"] - 1
)
bnb["Target_Return_365d"] = (
    bnb["Close"].shift(-365) / bnb["Close"] - 1
)
eth["Target_Return_365d"] = (
    eth["Close"].shift(-365) / eth["Close"] - 1
)
sol["Target_Return_365d"] = (
    sol["Close"].shift(-365) / sol["Close"] - 1
)
xrp["Target_Return_365d"] = (
    xrp["Close"].shift(-365) / xrp["Close"] - 1
)

# %%
btc["Target_Up"] = (btc["Target_Close"] > btc["Close"]).astype(int)
bnb["Target_Up"] = (bnb["Target_Close"] > bnb["Close"]).astype(int)
eth["Target_Up"] = (eth["Target_Close"] > eth["Close"]).astype(int)
xrp["Target_Up"] = (xrp["Target_Close"] > xrp["Close"]).astype(int)
sol["Target_Up"] = (sol["Target_Close"] > sol["Close"]).astype(int)

# %%
btc.info()
btc.describe()
btc.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1354 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
bnb.info()
bnb.describe()
bnb.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1454 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
eth.info()
eth.describe()
eth.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1296 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
sol.info()
sol.describe() 
sol.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1461 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
xrp.info()
xrp.describe()
xrp.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1461 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  MA_7                1455 non-null   float64
#  11  MA_21               1441 non-null   float64
#  12  MA_60               1402 non-null   float64
#  13  MA_180              1282 non-null   float64
#  14  Volatility_7        1454 non-null   float64
# ...

# %%
btc.dropna(inplace=True)
bnb.dropna(inplace=True)
eth.dropna(inplace=True)
xrp.dropna(inplace=True)
sol.dropna(inplace=True)
