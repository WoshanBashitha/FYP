# %%
import pandas as pd

# %% [markdown]
# Data loading

# %%
url = "https://drive.google.com/uc?id=1wvNExa2m2Mh_zY2ELWsE9skiKbDd8SSN"  
btc = pd.read_csv(url)
print(btc.head())
# Out:
#         Price            Close             High              Low  \
# 0      Ticker          BTC-USD          BTC-USD          BTC-USD
# 1        Date              NaN              NaN              NaN
# 2  2021-01-01   29374.15234375  29600.626953125    28803.5859375
# 3  2021-01-02  32127.267578125    33155.1171875  29091.181640625
# 4  2021-01-03    32782.0234375   34608.55859375   32052.31640625
#
#               Open       Volume
# 0          BTC-USD      BTC-USD
# 1              NaN          NaN
# 2  28994.009765625  40730301359
# 3  29376.455078125  67865420765
# 4  32129.408203125  78665235202

# %%
bnb_url = "https://drive.google.com/uc?id=1vgTWftWI8y289S8c8KE85ozsHSjWu_pg"  
bnb = pd.read_csv(bnb_url)
print(bnb.head())
# Out:
#         Price              Close               High                 Low  \
# 0      Ticker            BNB-USD            BNB-USD             BNB-USD
# 1        Date                NaN                NaN                 NaN
# 2  2021-01-01  37.90501022338867  38.92817687988281   37.04630661010742
# 3  2021-01-02  38.24159240722656  38.83625411987305  36.925601959228516
# 4  2021-01-03  41.14897918701172   41.6063232421875    37.8181037902832
#
#                  Open     Volume
# 0             BNB-USD    BNB-USD
# 1                 NaN        NaN
# 2   37.37457275390625  459165743
# 3   37.91710662841797  521965394
# 4  38.253726959228516  758008613

# %%
eth_url = "https://drive.google.com/uc?id=1ZMuVs5IW8FuJHWipbF0vWm1L-Xr-F-tg"  
eth = pd.read_csv(eth_url)
print(eth.head())
# Out:
#         Price              Close                High                Low  \
# 0      Ticker            ETH-USD             ETH-USD            ETH-USD
# 1        Date                NaN                 NaN                NaN
# 2  2021-01-01  730.3675537109375   749.2018432617188   719.792236328125
# 3  2021-01-02  774.5349731445312   786.7984619140625  718.1094970703125
# 4  2021-01-03  975.5076904296875  1006.5650024414062  771.5616455078125
#
#                 Open       Volume
# 0            ETH-USD      ETH-USD
# 1                NaN          NaN
# 2  737.7083740234375  13652004358
# 3  730.4026489257812  19740771179
# 4  774.5118408203125  45200463368

# %%
sol_url = "https://drive.google.com/uc?id=1jOH7TcSpB6MKiT9W4VpHCSzZzXyNMlNq"  
sol = pd.read_csv(sol_url)
print(sol.head())
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker             SOL-USD             SOL-USD             SOL-USD
# 1        Date                 NaN                 NaN                 NaN
# 2  2021-01-01  1.8420840501785278  1.8596559762954712  1.5020380020141602
# 3  2021-01-02  1.7992750406265259  1.9892950057983398  1.7214820384979248
# 4  2021-01-03  2.1617519855499268   2.364980936050415  1.7999019622802734
#
#                  Open    Volume
# 0             SOL-USD   SOL-USD
# 1                 NaN       NaN
# 2  1.5097750425338745  25722549
# 3  1.8455859422683716  31671064
# 4  1.7999019622802734  55073422

# %%
xrp_url = "https://drive.google.com/uc?id=1CS3d-1syse7EjpF5n5rjeW1yMJFsYLJx"
xrp = pd.read_csv(xrp_url)
print(xrp.head())
# Out:
#         Price                Close                 High                  Low  \
# 0      Ticker              XRP-USD              XRP-USD              XRP-USD
# 1        Date                  NaN                  NaN                  NaN
# 2  2021-01-01  0.23744399845600128   0.2492700070142746  0.21728800237178802
# 3  2021-01-02   0.2216549962759018  0.23838800191879272  0.21581600606441498
# 4  2021-01-03   0.2258480042219162  0.23774099349975586  0.21716700494289398
#
#                   Open      Volume
# 0              XRP-USD     XRP-USD
# 1                  NaN         NaN
# 2   0.2198449969291687  5888429287
# 3  0.23767000436782837  4773658725
# 4  0.22174400091171265  5109898871

# %% [markdown]
# Data preprocessing / cleaning

# %%
# to start the dataframe from the third row onwards
btc = btc.iloc[2:]
bnb = bnb.iloc[2:]
eth = eth.iloc[2:]
sol = sol.iloc[2:] 
xrp = xrp.iloc[2:]

# %%
print(btc.head())
print("\n")
print(btc.info())
# Out:
#         Price            Close             High              Low  \
# 2  2021-01-01   29374.15234375  29600.626953125    28803.5859375
# 3  2021-01-02  32127.267578125    33155.1171875  29091.181640625
# 4  2021-01-03    32782.0234375   34608.55859375   32052.31640625
# 5  2021-01-04    31971.9140625      33440.21875  28722.755859375
# 6  2021-01-05    33992.4296875   34437.58984375       30221.1875
#
#               Open       Volume
# 2  28994.009765625  40730301359
# 3  29376.455078125  67865420765
# 4  32129.408203125  78665235202
# 5   32810.94921875  81163475344
# 6  31977.041015625  67547324782
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
#  3   Low     1461 non-null   object
#  4   Open    1461 non-null   object
# ...

# %%
print(bnb.head())
print("\n")
print(bnb.info())
# Out:
#         Price               Close               High                 Low  \
# 2  2021-01-01   37.90501022338867  38.92817687988281   37.04630661010742
# 3  2021-01-02   38.24159240722656  38.83625411987305  36.925601959228516
# 4  2021-01-03   41.14897918701172   41.6063232421875    37.8181037902832
# 5  2021-01-04  40.926353454589844  43.13212203979492   38.14398193359375
# 6  2021-01-05   41.73460006713867  41.73460006713867   38.97895431518555
#
#                  Open     Volume
# 2   37.37457275390625  459165743
# 3   37.91710662841797  521965394
# 4  38.253726959228516  758008613
# 5  41.198280334472656  807877171
# 6  40.937278747558594  644270927
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
# ...

# %%
print(eth.head())
print("\n")
print(eth.info())
# Out:
#         Price               Close                High                Low  \
# 2  2021-01-01   730.3675537109375   749.2018432617188   719.792236328125
# 3  2021-01-02   774.5349731445312   786.7984619140625  718.1094970703125
# 4  2021-01-03   975.5076904296875  1006.5650024414062  771.5616455078125
# 5  2021-01-04  1040.2330322265625   1153.189208984375  912.3053588867188
# 6  2021-01-05   1100.006103515625  1129.3714599609375   986.811279296875
#
#                 Open       Volume
# 2  737.7083740234375  13652004358
# 3  730.4026489257812  19740771179
# 4  774.5118408203125  45200463368
# 5   977.058837890625  56945985763
# 6  1041.498779296875  41535932781
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
# ...

# %%
print(sol.head())
print("\n")
print(sol.info())
# Out:
#         Price               Close                High                 Low  \
# 2  2021-01-01  1.8420840501785278  1.8596559762954712  1.5020380020141602
# 3  2021-01-02  1.7992750406265259  1.9892950057983398  1.7214820384979248
# 4  2021-01-03  2.1617519855499268   2.364980936050415  1.7999019622802734
# 5  2021-01-04  2.4850969314575195  2.4850969314575195  1.8763420581817627
# 6  2021-01-05   2.157217025756836  2.5026159286499023   2.077742099761963
#
#                  Open    Volume
# 2  1.5097750425338745  25722549
# 3  1.8455859422683716  31671064
# 4  1.7999019622802734  55073422
# 5    2.16241192817688  59955405
# 6  2.4909820556640625  50555207
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
#  2   High    1461 non-null   object
# ...

# %%
print(xrp.head())
print("\n")
print(xrp.info())
# Out:
#         Price                Close                 High                  Low  \
# 2  2021-01-01  0.23744399845600128   0.2492700070142746  0.21728800237178802
# 3  2021-01-02   0.2216549962759018  0.23838800191879272  0.21581600606441498
# 4  2021-01-03   0.2258480042219162  0.23774099349975586  0.21716700494289398
# 5  2021-01-04  0.23667700588703156   0.2564769983291626  0.21972200274467468
# 6  2021-01-05  0.22675000131130219  0.24125100672245026  0.22160199284553528
#
#                   Open      Volume
# 2   0.2198449969291687  5888429287
# 3  0.23767000436782837  4773658725
# 4  0.22174400091171265  5109898871
# 5  0.22603799402713776  6141918380
# 6   0.2366359978914261  5378491929
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1461 non-null   object
#  1   Close   1461 non-null   object
# ...

# %%
# btc.isnull().sum()

# %%
# bnb.isnull().sum()

# %%
# eth.isnull().sum()

# %%
# sol.isnull().sum()

# %%
# xrp.isnull().sum()

# %%
for df, name in zip([btc, bnb, eth, sol, xrp], ["BTC", "BNB", "ETH", "SOL", "XRP"]):
    if df.isnull().any().any():
        print(f"{name}: Null values detected")
    else:
        print(f"{name}: No null values detected")
# Out:
# BTC: No null values detected
# BNB: No null values detected
# ETH: No null values detected
# SOL: No null values detected
# XRP: No null values detected

# %% [markdown]
# As there are no null values we do not need to fill null values

# %%
# btc.fillna(method="ffill", inplace=True)
# bnb.fillna(method="ffill", inplace=True)
# eth.fillna(method="ffill", inplace=True)
# sol.fillna(method="ffill", inplace=True)
# xrp.fillna(method="ffill", inplace=True)

# %%
print(btc.index )
print(bnb.index )
print(eth.index )
print(sol.index )
print(xrp.index )
# Out:
# RangeIndex(start=2, stop=1463, step=1)
# RangeIndex(start=2, stop=1463, step=1)
# RangeIndex(start=2, stop=1463, step=1)
# RangeIndex(start=2, stop=1463, step=1)
# RangeIndex(start=2, stop=1463, step=1)

# %%
# checks for duplicates in the index (the date column) which means there are two records for the same day 
btc = btc[~btc.index.duplicated()]
bnb = bnb[~bnb.index.duplicated()]
eth = eth[~eth.index.duplicated()]
sol = sol[~sol.index.duplicated()]
xrp = xrp[~xrp.index.duplicated()]

# %%
# checking for duplicates
for df, name in zip([btc, bnb, eth, sol, xrp], ["BTC", "BNB", "ETH", "SOL", "XRP"]):
    if df.duplicated().any():
        print(f"{name}: Duplicates detected")
    else:
        print(f"{name}: No duplicates detected")
    # Remove duplicates
    df = df[~df.duplicated()]
# Out:
# BTC: No duplicates detected
# BNB: No duplicates detected
# ETH: No duplicates detected
# SOL: No duplicates detected
# XRP: No duplicates detected

# %%
# renaming the colummns 
btc.columns = ["Date","Close","High","Low","Open","Volume"]
bnb.columns = ["Date","Close","High","Low","Open","Volume"]
eth.columns = ["Date","Close","High","Low","Open","Volume"]
sol.columns = ["Date","Close","High","Low","Open","Volume"]
xrp.columns = ["Date","Close","High","Low","Open","Volume"]

# %%
# example dataframe 
btc.head()
# Out:
#          Date            Close             High              Low  \
# 2  2021-01-01   29374.15234375  29600.626953125    28803.5859375
# 3  2021-01-02  32127.267578125    33155.1171875  29091.181640625
# 4  2021-01-03    32782.0234375   34608.55859375   32052.31640625
# 5  2021-01-04    31971.9140625      33440.21875  28722.755859375
# 6  2021-01-05    33992.4296875   34437.58984375       30221.1875
#
#               Open       Volume
# 2  28994.009765625  40730301359
# 3  29376.455078125  67865420765
# 4  32129.408203125  78665235202
# 5   32810.94921875  81163475344
# 6  31977.041015625  67547324782

# %%
# making the date column into Datetime format
btc["Date"] = pd.to_datetime(btc["Date"])
bnb["Date"] = pd.to_datetime(bnb["Date"])
eth["Date"] = pd.to_datetime(eth["Date"])
sol["Date"] = pd.to_datetime(sol["Date"])
xrp["Date"] = pd.to_datetime(xrp["Date"])

# %%
btc.reset_index(drop=True, inplace=True)
bnb.reset_index(drop=True, inplace=True)
eth.reset_index(drop=True, inplace=True)
sol.reset_index(drop=True, inplace=True)
xrp.reset_index(drop=True, inplace=True)

# %%
#checking the index after reseting
print(btc.index )
print(bnb.index )
print(eth.index )
print(sol.index )
print(xrp.index )
# Out:
# RangeIndex(start=0, stop=1461, step=1)
# RangeIndex(start=0, stop=1461, step=1)
# RangeIndex(start=0, stop=1461, step=1)
# RangeIndex(start=0, stop=1461, step=1)
# RangeIndex(start=0, stop=1461, step=1)

# %%
# setting the date column as the index 
for df in [btc, bnb, eth, sol, xrp]:
    df.set_index("Date", inplace=True)

# %%
#checking the index after reseting it to the date column
print(btc.index )
print(bnb.index )
print(eth.index )
print(sol.index )
print(xrp.index )
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2024-12-22', '2024-12-23', '2024-12-24', '2024-12-25',
#                '2024-12-26', '2024-12-27', '2024-12-28', '2024-12-29',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1461, freq=None)
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2024-12-22', '2024-12-23', '2024-12-24', '2024-12-25',
#                '2024-12-26', '2024-12-27', '2024-12-28', '2024-12-29',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1461, freq=None)
# ...

# %%
btc
# Out:
#                       Close             High              Low  \
# Date
# 2021-01-01   29374.15234375  29600.626953125    28803.5859375
# 2021-01-02  32127.267578125    33155.1171875  29091.181640625
# 2021-01-03    32782.0234375   34608.55859375   32052.31640625
# 2021-01-04    31971.9140625      33440.21875  28722.755859375
# 2021-01-05    33992.4296875   34437.58984375       30221.1875
# ...                     ...              ...              ...
# 2024-12-27     94164.859375      97294.84375    93310.7421875
# 2024-12-28    95163.9296875    95525.8984375    94014.2890625
# 2024-12-29    93530.2265625        95174.875    92881.7890625
# 2024-12-30    92643.2109375    94903.3203125    91317.1328125
# 2024-12-31     93429.203125    96090.6015625      91914.03125
#
#                        Open       Volume
# Date
# 2021-01-01  28994.009765625  40730301359
# 2021-01-02  29376.455078125  67865420765
# 2021-01-03  32129.408203125  78665235202
# ...

# %%
# Check whether the DataFrames have multi-level columns
for name, df in zip(["BTC", "BNB", "ETH", "SOL", "XRP"], [btc, bnb, eth, sol, xrp]):
    print(f"{name}: {isinstance(df.columns, pd.MultiIndex)}")
# Out:
# BTC: False
# BNB: False
# ETH: False
# SOL: False
# XRP: False

# %%
print(btc.info())
print("\n")
print(bnb.info())
print("\n")
print(eth.info())
print("\n")
print(sol.info())
print("\n")
print(xrp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2021-01-01 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1461 non-null   object
#  1   High    1461 non-null   object
#  2   Low     1461 non-null   object
#  3   Open    1461 non-null   object
#  4   Volume  1461 non-null   object
# dtypes: object(5)
# memory usage: 68.5+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2021-01-01 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1461 non-null   object
#  1   High    1461 non-null   object
#  2   Low     1461 non-null   object
#  3   Open    1461 non-null   object
#  4   Volume  1461 non-null   object
# dtypes: object(5)
# memory usage: 68.5+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2021-01-01 to 2024-12-31
# ...

# %%
btc = btc.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
bnb = bnb.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
eth = eth.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
sol = sol.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})
xrp = xrp.astype({
    "Close": float,
    "High": float,
    "Low": float,
    "Open": float,
    "Volume": float
})

# %%
print(btc.info())
print("\n")
print(bnb.info())
print("\n")
print(eth.info())
print("\n")
print(sol.info())
print("\n")
print(xrp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2021-01-01 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1461 non-null   float64
#  1   High    1461 non-null   float64
#  2   Low     1461 non-null   float64
#  3   Open    1461 non-null   float64
#  4   Volume  1461 non-null   float64
# dtypes: float64(5)
# memory usage: 68.5 KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2021-01-01 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1461 non-null   float64
#  1   High    1461 non-null   float64
#  2   Low     1461 non-null   float64
#  3   Open    1461 non-null   float64
#  4   Volume  1461 non-null   float64
# dtypes: float64(5)
# memory usage: 68.5 KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# Sort each DataFrame by the 'Date' column in ascending order to ensure chronological order for analysis and plotting
btc = btc.sort_values("Date")
bnb = bnb.sort_values("Date")
eth = eth.sort_values("Date")
sol = sol.sort_values("Date")
xrp = xrp.sort_values("Date")

# %%
# check for missing dates in each cryptocurrency time series
# helps identify if any days are missing in the dataset

crypto_dfs = {
    "BTC": btc,
    "BNB": bnb,
    "ETH": eth,
    "SOL": sol,
    "XRP": xrp
}

for name, df in crypto_dfs.items():
    df.index = pd.to_datetime(df.index)

    full_range = pd.date_range(
        start=df.index.min(),
        end=df.index.max(),
        freq="D"
    )

    missing_dates = full_range.difference(df.index)

    print(f"{name}: Missing dates = {len(missing_dates)}")
# Out:
# BTC: Missing dates = 0
# BNB: Missing dates = 0
# ETH: Missing dates = 0
# SOL: Missing dates = 0
# XRP: Missing dates = 0

# %%
#checking whether the dataset need scaling 
crypto_dfs = [btc, bnb, eth, sol, xrp]
crypto_names = ["BTC", "BNB", "ETH", "SOL", "XRP"]

for df, name in zip(crypto_dfs, crypto_names):
    stats = df[["Open","High","Low","Close","Volume"]].describe()
    print(f"\n{name} stats:\n", stats)
    
    # Check the ranges
    ranges = stats.loc["max"] - stats.loc["min"]
    if ranges.max() / ranges.min() > 100:  # if largest feature is 100x bigger than smallest
        print(f"{name}: Scaling is recommended due to large differences in feature ranges.\n")
    else:
        print(f"{name}: Scaling may not be strictly necessary.\n")
# Out:
# BTC stats:
#                  Open           High            Low          Close  \
# count    1461.000000    1461.000000    1461.000000    1461.000000
# mean    42589.579728   43526.305379   41608.042723   42630.544267
# std     18777.069927   19197.265489   18365.545906   18818.520965
# min     15782.300781   16253.047852   15599.046875   15787.284180
# 25%     27267.031250   27787.812500   26843.277344   27276.910156
# 50%     39744.515625   40777.757812   38746.347656   39773.828125
# 75%     57430.347656   58534.359375   55879.085938   57424.007812
# max    106147.296875  108268.445312  105291.734375  106140.601562
#
#              Volume
# count  1.461000e+03
# mean   3.321765e+10
# std    2.102848e+10
# min    5.331173e+09
# 25%    1.958810e+10
# 50%    2.912400e+10
# 75%    3.985613e+10
# max    3.509679e+11
# BTC: Scaling is recommended due to large differences in feature ranges.
#
#
# BNB stats:
#                Open         High          Low        Close        Volume
# ...

# %%
print("Dataframe:",btc.head())
print('\n')
print(btc.info())
print('\n')
print("Data types:", btc.dtypes)
# Out:
# Dataframe:                    Close          High           Low          Open  \
# Date
# 2021-01-01  29374.152344  29600.626953  28803.585938  28994.009766
# 2021-01-02  32127.267578  33155.117188  29091.181641  29376.455078
# 2021-01-03  32782.023438  34608.558594  32052.316406  32129.408203
# 2021-01-04  31971.914062  33440.218750  28722.755859  32810.949219
# 2021-01-05  33992.429688  34437.589844  30221.187500  31977.041016
#
#                   Volume
# Date
# 2021-01-01  4.073030e+10
# 2021-01-02  6.786542e+10
# 2021-01-03  7.866524e+10
# 2021-01-04  8.116348e+10
# 2021-01-05  6.754732e+10
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2021-01-01 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1461 non-null   float64
#  1   High    1461 non-null   float64
#  2   Low     1461 non-null   float64
#  3   Open    1461 non-null   float64
# ...

# %%
# Saving the preprocessed dataset in a separate folder
import os

# Create folder if it doesn't exist
os.makedirs("preprocessed_datasets", exist_ok=True)

# Dictionary of DataFrames
crypto_dfs = {"BTC": btc, "BNB": bnb, "ETH": eth, "SOL": sol, "XRP": xrp}

# Save each as CSV
for name, df in crypto_dfs.items():
    df.to_csv(f"preprocessed_datasets/{name}_preprocessed.csv", index=True)

# %% [markdown]
# ## EDA - new

# %% [markdown]
#  ### BTC

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(btc.index, btc["Close"])
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("BTC Close Price vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(btc.index, btc["Open"], label="Open", color ='red')
plt.plot(btc.index, btc["Close"], label="Close")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("BTC Open vs Close Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(btc.index, btc["High"], label="High",color ="green")
plt.plot(btc.index, btc["Low"], label="Low",color ="yellow")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("BTC High vs Low Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(btc.index, btc["Volume"], color='orange')
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("BTC Volume vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(btc["Close"], bins=50, color='blue', edgecolor='black')
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.title("Histogram of BTC Close Price")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(btc["Volume"], bins=50, color='orange', edgecolor='black')
plt.xlabel("Volume")
plt.ylabel("Frequency")
plt.title("Histogram of BTC Volume")

# Boxplot
plt.subplot(1, 2, 2)
plt.boxplot(btc["Volume"], patch_artist=True, boxprops=dict(facecolor="orange"))
plt.ylabel("Volume")
plt.title("Boxplot of BTC Volume")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation
corr = btc[["Open", "High", "Low", "Close", "Volume"]].corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of BTC Features")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(btc.index, btc["Close"], label="Close", color="blue")
plt.plot(btc.index, btc["Close"].rolling(window=7).mean(), label="7-day Rolling Mean", color="red")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("BTC Close Price with 7-day Rolling Mean")
plt.legend()
plt.show()

# %% [markdown]
# ### BNB

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(bnb.index, btc["Close"])
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("BNB Close Price vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(bnb.index, bnb["Open"], label="Open", color ='red')
plt.plot(bnb.index, bnb["Close"], label="Close")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("BNB Open vs Close Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(bnb.index, bnb["High"], label="High",color ="green")
plt.plot(bnb.index, bnb["Low"], label="Low",color ="yellow")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("BNB High vs Low Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(bnb.index, bnb["Volume"], color='orange')
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("BNB Volume vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(bnb["Close"], bins=50, color='blue', edgecolor='black')
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.title("Histogram of BNB Close Price")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(bnb["Volume"], bins=50, color='orange', edgecolor='black')
plt.xlabel("Volume")
plt.ylabel("Frequency")
plt.title("Histogram of BNB Volume")

# Boxplot
plt.subplot(1, 2, 2)
plt.boxplot(bnb["Volume"], patch_artist=True, boxprops=dict(facecolor="orange"))
plt.ylabel("Volume")
plt.title("Boxplot of BNB Volume")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation
corr = bnb[["Open", "High", "Low", "Close", "Volume"]].corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of BNB Features")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(bnb.index, bnb["Close"], label="Close", color="blue")
plt.plot(bnb.index, bnb["Close"].rolling(window=7).mean(), label="7-day Rolling Mean", color="red")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("BNB Close Price with 7-day Rolling Mean")
plt.legend()
plt.show()

# %% [markdown]
# ### ETH

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(eth.index, eth["Close"])
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("ETH Close Price vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(eth.index, eth["Open"], label="Open", color ='red')
plt.plot(eth.index, eth["Close"], label="Close")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("ETH Open vs Close Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(eth.index, eth["High"], label="High",color ="green")
plt.plot(eth.index, eth["Low"], label="Low",color ="yellow")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("ETH High vs Low Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(eth.index, eth["Volume"], color='orange')
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("ETH Volume vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(eth["Close"], bins=50, color='blue', edgecolor='black')
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.title("Histogram of ETH Close Price")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(eth["Volume"], bins=50, color='orange', edgecolor='black')
plt.xlabel("Volume")
plt.ylabel("Frequency")
plt.title("Histogram of ETH Volume")

# Boxplot
plt.subplot(1, 2, 2)
plt.boxplot(eth["Volume"], patch_artist=True, boxprops=dict(facecolor="orange"))
plt.ylabel("Volume")
plt.title("Boxplot of ETH Volume")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation
corr = eth[["Open", "High", "Low", "Close", "Volume"]].corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of ETH Features")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(eth.index, eth["Close"], label="Close", color="blue")
plt.plot(eth.index, eth["Close"].rolling(window=7).mean(), label="7-day Rolling Mean", color="red")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("ETH Close Price with 7-day Rolling Mean")
plt.legend()
plt.show()

# %% [markdown]
# ### SOL

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(sol.index, sol["Close"])
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("SOL Close Price vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(sol.index, sol["Open"], label="Open", color ='red')
plt.plot(sol.index, sol["Close"], label="Close")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("SOL Open vs Close Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(sol.index, sol["High"], label="High",color ="green")
plt.plot(sol.index, sol["Low"], label="Low",color ="yellow")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("SOL High vs Low Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(sol.index, sol["Volume"], color='orange')
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("SOL Volume vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(sol["Close"], bins=50, color='blue', edgecolor='black')
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.title("Histogram of SOL Close Price")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(sol["Volume"], bins=50, color='orange', edgecolor='black')
plt.xlabel("Volume")
plt.ylabel("Frequency")
plt.title("Histogram of SOL Volume")

# Boxplot
plt.subplot(1, 2, 2)
plt.boxplot(sol["Volume"], patch_artist=True, boxprops=dict(facecolor="orange"))
plt.ylabel("Volume")
plt.title("Boxplot of SOL Volume")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation
corr = sol[["Open", "High", "Low", "Close", "Volume"]].corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of ETH Features")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(sol.index, sol["Close"], label="Close", color="blue")
plt.plot(sol.index, sol["Close"].rolling(window=7).mean(), label="7-day Rolling Mean", color="red")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("SOL Close Price with 7-day Rolling Mean")
plt.legend()
plt.show()

# %% [markdown]
# ### XRP

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(xrp.index, xrp["Close"])
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("XRP Close Price vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(xrp.index, xrp["Open"], label="Open", color ='red')
plt.plot(xrp.index, xrp["Close"], label="Close")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("XRP Open vs Close Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(xrp.index, xrp["High"], label="High",color ="green")
plt.plot(xrp.index, xrp["Low"], label="Low",color ="yellow")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("XRP High vs Low Price")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(xrp.index, xrp["Volume"], color='orange')
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("XRP Volume vs Date")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(xrp["Close"], bins=50, color='blue', edgecolor='black')
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.title("Histogram of XRP Close Price")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(xrp["Volume"], bins=50, color='orange', edgecolor='black')
plt.xlabel("Volume")
plt.ylabel("Frequency")
plt.title("Histogram of XRP Volume")

# Boxplot
plt.subplot(1, 2, 2)
plt.boxplot(xrp["Volume"], patch_artist=True, boxprops=dict(facecolor="orange"))
plt.ylabel("Volume")
plt.title("Boxplot of XRP Volume")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation
corr = xrp[["Open", "High", "Low", "Close", "Volume"]].corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of XRP Features")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(xrp.index, xrp["Close"], label="Close", color="blue")
plt.plot(xrp.index, xrp["Close"].rolling(window=7).mean(), label="7-day Rolling Mean", color="red")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("XRP Close Price with 7-day Rolling Mean")
plt.legend()
plt.show()

# %% [markdown]
# ## Feature engineering - New

# %%
from feature_engineering import calculate_features

# %%
import pandas as pd
from feature_engineering import calculate_features  # use your module

# Load preprocessed datasets
btc = pd.read_csv("preprocessed_datasets/BTC_preprocessed.csv")
eth = pd.read_csv("preprocessed_datasets/ETH_preprocessed.csv")
bnb = pd.read_csv("preprocessed_datasets/BNB_preprocessed.csv")
sol = pd.read_csv("preprocessed_datasets/SOL_preprocessed.csv")
xrp = pd.read_csv("preprocessed_datasets/XRP_preprocessed.csv")

# Dictionary of all coins
coins = {
    "BTC": btc,
    "BNB": bnb,
    "ETH": eth,
    "SOL": sol,
    "XRP": xrp
}

# Apply feature engineering 
processed_coins = {}
for name, df in coins.items():
    processed_coins[name] = calculate_features(df)
    print(f"Features calculated for {name}")
# Out:
# Features calculated for BTC
# Features calculated for BNB
# Features calculated for ETH
# Features calculated for SOL
# Features calculated for XRP

# %%
import os
from feature_engineering import calculate_features

# Create folder if it doesn't exist
os.makedirs("feature_datasets", exist_ok=True)

# Dictionary of preprocessed DataFrames
crypto_dfs = {"BTC": btc, "BNB": bnb, "ETH": eth, "SOL": sol, "XRP": xrp}

# Apply feature engineering and save each
for name, df in crypto_dfs.items():
    processed_df = calculate_features(df)
    processed_df.to_csv(f"feature_datasets/{name}_features.csv", index=True)
    print(f"Saved {name}_features.csv")
# Out:
# Saved BTC_features.csv
# Saved BNB_features.csv
# Saved ETH_features.csv
# Saved SOL_features.csv
# Saved XRP_features.csv

# %% [markdown]
# ## previous scaling code

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# features = ["Close", "High", "Low", "Open", "Volume"]
# btc[features] = scaler.fit_transform(btc[features])

# %%
# scaler = StandardScaler()
# features = ["Close", "High", "Low", "Open", "Volume"]
# bnb[features] = scaler.fit_transform(bnb[features])

# %%
# scaler = StandardScaler()
# features = ["Close", "High", "Low", "Open", "Volume"]
# eth[features] = scaler.fit_transform(eth[features])

# %%
# scaler = StandardScaler()
# features = ["Close", "High", "Low", "Open", "Volume"]
# sol[features] = scaler.fit_transform(sol[features])

# %%
# scaler = StandardScaler()
# features = ["Close", "High", "Low", "Open", "Volume"]
# xrp[features] = scaler.fit_transform(xrp[features])

# %% [markdown]
# ## Previous EDA and Feature engineering

# %%
import matplotlib.pyplot as plt
btc.describe()
# Out:
#                Close           High            Low           Open  \
# count    1461.000000    1461.000000    1461.000000    1461.000000
# mean    42630.544267   43526.305379   41608.042723   42589.579728
# std     18818.520965   19197.265489   18365.545906   18777.069927
# min     15787.284180   16253.047852   15599.046875   15782.300781
# 25%     27276.910156   27787.812500   26843.277344   27267.031250
# 50%     39773.828125   40777.757812   38746.347656   39744.515625
# 75%     57424.007812   58534.359375   55879.085938   57430.347656
# max    106140.601562  108268.445312  105291.734375  106147.296875
#
#              Volume
# count  1.461000e+03
# mean   3.321765e+10
# std    2.102848e+10
# min    5.331173e+09
# 25%    1.958810e+10
# 50%    2.912400e+10
# 75%    3.985613e+10
# max    3.509679e+11

# %%
bnb.describe()
# Out:
#              Close         High          Low         Open        Volume
# count  1461.000000  1461.000000  1461.000000  1461.000000  1.461000e+03
# mean    378.244703   387.754376   367.409658   377.833255  1.693346e+09
# std     150.333225   154.206200   146.286564   150.433985  1.440548e+09
# min      37.905010    38.836254    35.170883    37.374573  2.038465e+08
# 25%     269.567169   276.159790   261.730255   269.559021  7.140009e+08
# 50%     323.870148   332.877777   316.711060   323.871613  1.451550e+09
# 75%     519.870361   533.371033   503.233856   519.870361  2.067449e+09
# max     750.272644   793.350525   730.873962   751.731934  1.798295e+10

# %%
eth.describe()
# Out:
#              Close         High          Low         Open        Volume
# count  1461.000000  1461.000000  1461.000000  1461.000000  1.461000e+03
# mean   2401.898383  2464.458279  2330.693083  2400.367672  1.731035e+10
# std     872.954379   898.461629   845.556060   874.180412  1.140317e+10
# min     730.367554   749.201843   718.109497   730.402649  2.081626e+09
# 25%    1678.650146  1724.789185  1642.396729  1677.605713  9.180418e+09
# 50%    2243.215820  2310.713135  2168.885010  2242.012695  1.519823e+10
# 75%    3104.106445  3184.435547  3026.538818  3103.619629  2.187163e+10
# max    4812.087402  4891.704590  4718.039062  4810.071289  8.448291e+10

# %%
sol.describe()
# Out:
#              Close         High          Low         Open        Volume
# count  1461.000000  1461.000000  1461.000000  1461.000000  1.461000e+03
# mean     80.744738    83.881793    77.439061    80.637575  1.858555e+09
# std      67.064241    69.398034    64.539940    67.070602  1.930338e+09
# min       1.799275     1.859656     1.502038     1.509775  2.572255e+07
# 25%      23.192671    23.998753    22.400766    23.185406  4.724493e+08
# 50%      43.491211    46.071491    41.642551    43.474380  1.323280e+09
# 75%     141.348450   145.540970   135.582703   141.374146  2.588808e+09
# max     258.934326   263.831543   253.187439   258.781555  1.706864e+10

# %%
xrp.describe()
# Out:
#              Close         High          Low         Open        Volume
# count  1461.000000  1461.000000  1461.000000  1461.000000  1.461000e+03
# mean      0.657962     0.680986     0.631765     0.656661  3.030210e+09
# std       0.363212     0.384952     0.338073     0.361346  4.299785e+09
# min       0.221655     0.237741     0.215816     0.219845  2.253910e+08
# 25%       0.462879     0.471252     0.447824     0.462822  1.021918e+09
# 50%       0.543658     0.558367     0.527192     0.543660  1.586138e+09
# 75%       0.733178     0.761583     0.707289     0.732982  3.120943e+09
# max       2.713805     2.864887     2.492445     2.713920  5.172338e+10

# %% [markdown]
# EDA

# %%
btc["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
bnb["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
eth["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
sol["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Close"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["High"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Low"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Open"].hist(bins=60)
# Out:
# <Axes: >

# %%
xrp["Volume"].hist(bins=60)
# Out:
# <Axes: >

# %%
btc.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
bnb.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
eth.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
sol.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
xrp.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
btc["Volume"].skew()
# Out:
# np.float64(3.651879318481497)

# %%
bnb["Volume"].skew()
# Out:
# np.float64(3.208930372042954)

# %%
eth["Volume"].skew()
# Out:
# np.float64(1.608610427009391)

# %%
sol["Volume"].skew()
# Out:
# np.float64(2.4774207995409423)

# %%
xrp["Volume"].skew()
# Out:
# np.float64(4.459214292764925)

# %%
import numpy as np
btc["Volume"] = np.log1p(btc["Volume"])
bnb["Volume"] = np.log1p(bnb["Volume"])
eth["Volume"] = np.log1p(eth["Volume"])
sol["Volume"] = np.log1p(sol["Volume"])
xrp["Volume"] = np.log1p(xrp["Volume"])

# %%
btc.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
bnb.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
eth.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
sol.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
xrp.boxplot(column="Volume")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

btc["Daily_Return"] = btc["Close"].pct_change()
btc[["Date", "Close", "Daily_Return"]].head()
# Out:
#          Date         Close  Daily_Return
# 0  2021-01-01  29374.152344           NaN
# 1  2021-01-02  32127.267578      0.093726
# 2  2021-01-03  32782.023438      0.020380
# 3  2021-01-04  31971.914062     -0.024712
# 4  2021-01-05  33992.429688      0.063197

# %%
btc["Daily_Return"].plot()
plt.show()

# %%
bnb["Daily_Return"] = bnb["Close"].pct_change()
bnb[["Date", "Close", "Daily_Return"]].head()
# Out:
#          Date      Close  Daily_Return
# 0  2021-01-01  37.905010           NaN
# 1  2021-01-02  38.241592      0.008880
# 2  2021-01-03  41.148979      0.076027
# 3  2021-01-04  40.926353     -0.005410
# 4  2021-01-05  41.734600      0.019749

# %%
bnb["Daily_Return"].plot()
plt.show()

# %%
eth["Daily_Return"] = eth["Close"].pct_change()
eth[["Date", "Close", "Daily_Return"]].head()
# Out:
#          Date        Close  Daily_Return
# 0  2021-01-01   730.367554           NaN
# 1  2021-01-02   774.534973      0.060473
# 2  2021-01-03   975.507690      0.259475
# 3  2021-01-04  1040.233032      0.066350
# 4  2021-01-05  1100.006104      0.057461

# %%
eth["Daily_Return"].plot()
plt.show()

# %%
sol["Daily_Return"] = sol["Close"].pct_change()
sol[["Date", "Close", "Daily_Return"]].head()
# Out:
#          Date     Close  Daily_Return
# 0  2021-01-01  1.842084           NaN
# 1  2021-01-02  1.799275     -0.023239
# 2  2021-01-03  2.161752      0.201457
# 3  2021-01-04  2.485097      0.149575
# 4  2021-01-05  2.157217     -0.131938

# %%
sol["Daily_Return"].plot()
plt.show()

# %%
xrp["Daily_Return"] = xrp["Close"].pct_change()
xrp[["Date", "Close", "Daily_Return"]].head()
# Out:
#          Date     Close  Daily_Return
# 0  2021-01-01  0.237444           NaN
# 1  2021-01-02  0.221655     -0.066496
# 2  2021-01-03  0.225848      0.018917
# 3  2021-01-04  0.236677      0.047948
# 4  2021-01-05  0.226750     -0.041943

# %%
xrp["Daily_Return"].plot()
plt.show()

# %%
btc["Volume"].describe()
# Out:
# count    1461.000000
# mean       24.069686
# std         0.558724
# min        22.396837
# 25%        23.698188
# 50%        24.094828
# 75%        24.408542
# max        26.583961
# Name: Volume, dtype: float64

# %%
btc["Volume"].plot()
plt.show()

# %%
bnb["Volume"].describe()
# Out:
# count    1461.000000
# mean       20.971266
# std         0.754472
# min        19.132878
# 25%        20.386395
# 50%        21.095898
# 75%        21.449581
# max        23.612690
# Name: Volume, dtype: float64

# %%
bnb["Volume"].plot()
plt.show()

# %%
eth["Volume"].describe()
# Out:
# count    1461.000000
# mean       23.371973
# std         0.654120
# min        21.456415
# 25%        22.940339
# 50%        23.444445
# 75%        23.808456
# max        25.159815
# Name: Volume, dtype: float64

# %%
eth["Volume"].plot()
plt.show()

# %%
sol["Volume"].describe()
# Out:
# count    1461.000000
# mean       20.802367
# std         1.157344
# min        17.062879
# 25%        19.973441
# 50%        21.003379
# 75%        21.674463
# max        23.560509
# Name: Volume, dtype: float64

# %%
sol["Volume"].plot()
plt.show()

# %%
xrp["Volume"].describe()
# Out:
# count    1461.000000
# mean       21.358138
# std         0.875561
# min        19.233347
# 25%        20.744947
# 50%        21.184568
# 75%        21.861401
# max        24.669176
# Name: Volume, dtype: float64

# %%
xrp["Volume"].plot()
plt.show()

# %%
btc["Close_lag_1"] = btc["Close"].shift(1)
btc["Close_lag_7"] = btc["Close"].shift(7)
btc["Close_lag_14"] = btc["Close"].shift(14)

# %%
btc["Close_lag_30"] = btc["Close"].shift(30)
btc["Close_lag_90"] = btc["Close"].shift(90)
btc["Close_lag_180"] = btc["Close"].shift(180)

# %%
bnb["Close_lag_1"] = bnb["Close"].shift(1)
bnb["Close_lag_7"] = bnb["Close"].shift(7)
bnb["Close_lag_14"] = bnb["Close"].shift(14)

# %%
bnb["Close_lag_30"] = bnb["Close"].shift(30)
bnb["Close_lag_90"] = bnb["Close"].shift(90)
bnb["Close_lag_180"] = bnb["Close"].shift(180)

# %%
eth["Close_lag_1"] = eth["Close"].shift(1)
eth["Close_lag_7"] = eth["Close"].shift(7)
eth["Close_lag_14"] = eth["Close"].shift(14)

# %%
eth["Close_lag_30"] = eth["Close"].shift(30)
eth["Close_lag_90"] = eth["Close"].shift(90)
eth["Close_lag_180"] = eth["Close"].shift(180)

# %%
sol["Close_lag_1"] = sol["Close"].shift(1)
sol["Close_lag_7"] = sol["Close"].shift(7)
sol["Close_lag_14"] = sol["Close"].shift(14)

# %%
sol["Close_lag_30"] = sol["Close"].shift(30)
sol["Close_lag_90"] = sol["Close"].shift(90)
sol["Close_lag_180"] = sol["Close"].shift(180)

# %%
xrp["Close_lag_1"] = xrp["Close"].shift(1)
xrp["Close_lag_7"] = xrp["Close"].shift(7)
xrp["Close_lag_14"] = xrp["Close"].shift(14)

# %%
xrp["Close_lag_30"] = xrp["Close"].shift(30)
xrp["Close_lag_90"] = xrp["Close"].shift(90)
xrp["Close_lag_180"] = xrp["Close"].shift(180)

# %%
btc["MA_7"] = btc["Close"].rolling(7).mean()
btc["MA_21"] = btc["Close"].rolling(21).mean()
btc["MA_60"] = btc["Close"].rolling(60).mean()
btc["MA_180"] = btc["Close"].rolling(180).mean()

# %%
bnb["MA_7"] = bnb["Close"].rolling(7).mean()
bnb["MA_21"] = bnb["Close"].rolling(21).mean()
bnb["MA_60"] = bnb["Close"].rolling(60).mean()
bnb["MA_180"] = bnb["Close"].rolling(180).mean()

# %%
eth["MA_7"] = eth["Close"].rolling(7).mean()
eth["MA_21"] = eth["Close"].rolling(21).mean()
eth["MA_60"] = eth["Close"].rolling(60).mean()
eth["MA_180"] = eth["Close"].rolling(180).mean()

# %%
sol["MA_7"] = sol["Close"].rolling(7).mean()
sol["MA_21"] = sol["Close"].rolling(21).mean()
sol["MA_60"] = sol["Close"].rolling(60).mean()
sol["MA_180"] = sol["Close"].rolling(180).mean()

# %%
xrp["MA_7"] = xrp["Close"].rolling(7).mean()
xrp["MA_21"] = xrp["Close"].rolling(21).mean()
xrp["MA_60"] = xrp["Close"].rolling(60).mean()
xrp["MA_180"] = xrp["Close"].rolling(180).mean()

# %%
btc["Volatility_7"] = btc["Daily_Return"].rolling(7).std()
btc["Volatility_21"] = btc["Daily_Return"].rolling(21).std()
btc["Volatility_60"] = btc["Daily_Return"].rolling(60).std()
btc["Volatility_180"] = btc["Daily_Return"].rolling(180).std()

# %%
bnb["Volatility_7"] = bnb["Daily_Return"].rolling(7).std()
bnb["Volatility_21"] = bnb["Daily_Return"].rolling(21).std()
bnb["Volatility_60"] = bnb["Daily_Return"].rolling(60).std()
bnb["Volatility_180"] = bnb["Daily_Return"].rolling(180).std()

# %%
eth["Volatility_7"] = eth["Daily_Return"].rolling(7).std()
eth["Volatility_21"] = eth["Daily_Return"].rolling(21).std()
eth["Volatility_60"] = eth["Daily_Return"].rolling(60).std()
eth["Volatility_180"] = eth["Daily_Return"].rolling(180).std()

# %%
sol["Volatility_7"] = sol["Daily_Return"].rolling(7).std()
sol["Volatility_21"] = sol["Daily_Return"].rolling(21).std()
sol["Volatility_60"] = sol["Daily_Return"].rolling(60).std()
sol["Volatility_180"] = sol["Daily_Return"].rolling(180).std()

# %%
xrp["Volatility_7"] = xrp["Daily_Return"].rolling(7).std()
xrp["Volatility_21"] = xrp["Daily_Return"].rolling(21).std()
xrp["Volatility_60"] = xrp["Daily_Return"].rolling(60).std()
xrp["Volatility_180"] = xrp["Daily_Return"].rolling(180).std()

# %%
btc["HL_Spread"] = (btc["High"] - btc["Low"]) / btc["Close"]

# %%
bnb["HL_Spread"] = (bnb["High"] - bnb["Low"]) / bnb["Close"]

# %%
eth["HL_Spread"] = (eth["High"] - eth["Low"]) / eth["Close"]

# %%
sol["HL_Spread"] = (sol["High"] - sol["Low"]) / sol["Close"]

# %%
xrp["HL_Spread"] = (xrp["High"] - xrp["Low"]) / xrp["Close"]

# %%
btc["Volume_MA_7"] = btc["Volume"].rolling(7).mean()
btc["Volume_MA_21"] = btc["Volume"].rolling(21).mean()
btc["Volume_MA_60"] = btc["Volume"].rolling(60).mean()
btc["Volume_MA_180"] = btc["Volume"].rolling(180).mean()
btc["Volume_Change"] = btc["Volume"].pct_change()

# %%
bnb["Volume_MA_7"] = bnb["Volume"].rolling(7).mean()
bnb["Volume_MA_21"] = bnb["Volume"].rolling(21).mean()
bnb["Volume_MA_60"] = bnb["Volume"].rolling(60).mean()
bnb["Volume_MA_180"] = bnb["Volume"].rolling(180).mean()
bnb["Volume_Change"] = bnb["Volume"].pct_change()

# %%
eth["Volume_MA_7"] = eth["Volume"].rolling(7).mean()
eth["Volume_MA_21"] = eth["Volume"].rolling(21).mean() 
eth["Volume_MA_60"] = eth["Volume"].rolling(60).mean()
eth["Volume_MA_180"] = eth["Volume"].rolling(180).mean()
eth["Volume_Change"] = eth["Volume"].pct_change()

# %%
sol["Volume_MA_7"] = sol["Volume"].rolling(7).mean()
sol["Volume_MA_21"] = sol["Volume"].rolling(21).mean()
sol["Volume_MA_60"] = sol["Volume"].rolling(60).mean()
sol["Volume_MA_180"] = sol["Volume"].rolling(180).mean()
sol["Volume_Change"] = sol["Volume"].pct_change()

# %%
xrp["Volume_MA_7"] = xrp["Volume"].rolling(7).mean()
xrp["Volume_MA_21"] = xrp["Volume"].rolling(21).mean()
xrp["Volume_MA_60"] = xrp["Volume"].rolling(60).mean()
xrp["Volume_MA_180"] = xrp["Volume"].rolling(180).mean()
xrp["Volume_Change"] = xrp["Volume"].pct_change()

# %%
btc["Target_Close"] = btc["Close"].shift(-1)
bnb["Target_Close"] = bnb["Close"].shift(-1)
eth["Target_Close"] = eth["Close"].shift(-1)   
xrp["Target_Close"] = xrp["Close"].shift(-1)
sol["Target_Close"] = sol["Close"].shift(-1)

# %%
btc["Target_Return_7d"] = (
    btc["Close"].shift(-7) / btc["Close"] - 1
)
bnb["Target_Return_7d"] = (
    bnb["Close"].shift(-7) / bnb["Close"] - 1
)
eth["Target_Return_7d"] = (
    eth["Close"].shift(-7) / eth["Close"] - 1
)
sol["Target_Return_7d"] = (
    sol["Close"].shift(-7) / sol["Close"] - 1
)
xrp["Target_Return_7d"] = (
    xrp["Close"].shift(-7) / xrp["Close"] - 1
)

# %%
btc["Target_Return_30d"] = (
    btc["Close"].shift(-30) / btc["Close"] - 1
)
bnb["Target_Return_30d"] = (
    bnb["Close"].shift(-30) / bnb["Close"] - 1
)
eth["Target_Return_30d"] = (
    eth["Close"].shift(-30) / eth["Close"] - 1
)
sol["Target_Return_30d"] = (
    sol["Close"].shift(-30) / sol["Close"] - 1
)
xrp["Target_Return_30d"] = (
    xrp["Close"].shift(-30) / xrp["Close"] - 1
)

# %%
btc["Target_Return_365d"] = (
    btc["Close"].shift(-365) / btc["Close"] - 1
)
bnb["Target_Return_365d"] = (
    bnb["Close"].shift(-365) / bnb["Close"] - 1
)
eth["Target_Return_365d"] = (
    eth["Close"].shift(-365) / eth["Close"] - 1
)
sol["Target_Return_365d"] = (
    sol["Close"].shift(-365) / sol["Close"] - 1
)
xrp["Target_Return_365d"] = (
    xrp["Close"].shift(-365) / xrp["Close"] - 1
)

# %%
btc["Target_Up"] = (btc["Target_Close"] > btc["Close"]).astype(int)
bnb["Target_Up"] = (bnb["Target_Close"] > bnb["Close"]).astype(int)
eth["Target_Up"] = (eth["Target_Close"] > eth["Close"]).astype(int)
xrp["Target_Up"] = (xrp["Target_Close"] > xrp["Close"]).astype(int)
sol["Target_Up"] = (sol["Target_Close"] > sol["Close"]).astype(int)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
corr = btc.corr()  
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("BTC Feature Correlation Heatmap")
plt.show()

features_to_plot = ["Close_lag_1", "Close_lag_7", "MA_7", "MA_21", "Volatility_7", "Volatility_21"]

for feature in features_to_plot:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=btc[feature], y=btc["Target_Close"])
    plt.title(f"{feature} vs Target_Close")
    plt.xlabel(feature)
    plt.ylabel("Target_Close")
    plt.show()

return_features = ["Daily_Return", "Volatility_7", "Volatility_21"]

for feature in return_features:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=btc[feature], y=btc["Target_Return_7d"])
    plt.title(f"{feature} vs Target_Return_7d")
    plt.xlabel(feature)
    plt.ylabel("Target_Return_7d")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[189], line 5
#       2 import seaborn as sns
#       4 plt.figure(figsize=(12,8))
# ----> 5 corr = btc.corr()
#       6 sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
#       7 plt.title("BTC Feature Correlation Heatmap")
#
# File c:\Users\tharu\anaconda3\envs\Streamlit\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\tharu\anaconda3\envs\Streamlit\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
corr = bnb.corr()  
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("BNB Feature Correlation Heatmap")
plt.show()

features_to_plot = ["Close_lag_1", "Close_lag_7", "MA_7", "MA_21", "Volatility_7", "Volatility_21"]

for feature in features_to_plot:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=bnb[feature], y=bnb["Target_Close"])
    plt.title(f"{feature} vs Target_Close")
    plt.xlabel(feature)
    plt.ylabel("Target_Close")
    plt.show()

return_features = ["Daily_Return", "Volatility_7", "Volatility_21"]

for feature in return_features:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=bnb[feature], y=bnb["Target_Return_7d"])
    plt.title(f"{feature} vs Target_Return_7d")
    plt.xlabel(feature)
    plt.ylabel("Target_Return_7d")
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
corr = eth.corr()  
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("ETH Feature Correlation Heatmap")
plt.show()

features_to_plot = ["Close_lag_1", "Close_lag_7", "MA_7", "MA_21", "Volatility_7", "Volatility_21"]

for feature in features_to_plot:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=eth[feature], y=eth["Target_Close"])
    plt.title(f"{feature} vs Target_Close")
    plt.xlabel(feature)
    plt.ylabel("Target_Close")
    plt.show()

return_features = ["Daily_Return", "Volatility_7", "Volatility_21"]

for feature in return_features:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=eth[feature], y=eth["Target_Return_7d"])
    plt.title(f"{feature} vs Target_Return_7d")
    plt.xlabel(feature)
    plt.ylabel("Target_Return_7d")
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
corr = sol.corr()  
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("SOL Feature Correlation Heatmap")
plt.show()

features_to_plot = ["Close_lag_1", "Close_lag_7", "MA_7", "MA_21", "Volatility_7", "Volatility_21"]

for feature in features_to_plot:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=sol[feature], y=sol["Target_Close"])
    plt.title(f"{feature} vs Target_Close")
    plt.xlabel(feature)
    plt.ylabel("Target_Close")
    plt.show()

return_features = ["Daily_Return", "Volatility_7", "Volatility_21"]

for feature in return_features:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=sol[feature], y=sol["Target_Return_7d"])
    plt.title(f"{feature} vs Target_Return_7d")
    plt.xlabel(feature)
    plt.ylabel("Target_Return_7d")
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
corr = xrp.corr()  
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("XRP Feature Correlation Heatmap")
plt.show()

features_to_plot = ["Close_lag_1", "Close_lag_7", "MA_7", "MA_21", "Volatility_7", "Volatility_21"]

for feature in features_to_plot:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=xrp[feature], y=xrp["Target_Close"])
    plt.title(f"{feature} vs Target_Close")
    plt.xlabel(feature)
    plt.ylabel("Target_Close")
    plt.show()

return_features = ["Daily_Return", "Volatility_7", "Volatility_21"]

for feature in return_features:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=xrp[feature], y=xrp["Target_Return_7d"])
    plt.title(f"{feature} vs Target_Return_7d")
    plt.xlabel(feature)
    plt.ylabel("Target_Return_7d")
    plt.show()

# %%
btc.info()
btc.describe()
btc.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1354 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
bnb.info()
bnb.describe()
bnb.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1454 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
eth.info()
eth.describe()
eth.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1296 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
sol.info()
sol.describe() 
sol.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1461 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
xrp.info()
xrp.describe()
xrp.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 2 to 1462
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1461 non-null   datetime64[ns]
#  1   Close               1461 non-null   float64
#  2   High                1461 non-null   float64
#  3   Low                 1461 non-null   float64
#  4   Open                1461 non-null   float64
#  5   Volume              1461 non-null   float64
#  6   Daily_Return        1460 non-null   float64
#  7   Close_lag_1         1460 non-null   float64
#  8   Close_lag_7         1454 non-null   float64
#  9   Close_lag_14        1447 non-null   float64
#  10  Close_lag_30        1431 non-null   float64
#  11  Close_lag_90        1371 non-null   float64
#  12  Close_lag_180       1281 non-null   float64
#  13  MA_7                1455 non-null   float64
#  14  MA_21               1441 non-null   float64
# ...

# %%
btc.dropna(inplace=True)
bnb.dropna(inplace=True)
eth.dropna(inplace=True)
xrp.dropna(inplace=True)
sol.dropna(inplace=True)
